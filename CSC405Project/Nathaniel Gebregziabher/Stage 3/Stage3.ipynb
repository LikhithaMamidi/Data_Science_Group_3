# %% [markdown]
# # Question 1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import binom, skew, poisson,norm


cases_data= pd.read_csv("covid_confirmed_usafacts (1).csv")

df= pd.DataFrame(cases_data)

Florida_df= df[df['State']=='FL']

##Florida_df.head()
data_FL =Florida_df.iloc[:,4:].values.flatten()
dates
# Out:
# array([   0,    0,    0, ..., 7731, 7731, 7731], dtype=int64)

# %%
plt.hist(data_FL, bins=50, alpha=0.7, density=True, label='Data')

# Fit a normal distribution
mu = np.mean(data_FL)  # Mean of the sample
sigma = np.std(data_FL)  # Standard deviation of the sample
x = np.linspace(np.min(data_FL), np.max(data_FL), 100)
plt.plot(x, norm.pdf(x, mu, sigma), 'r-', label='Normal fit')

plt.xlabel('Values')
plt.ylabel('Probability Density')
plt.title('Histogram and Normal Fit for PMF (FL)')
plt.legend()
plt.grid(True)
plt.show()

mean = n * p

# Calculate variance
variance = n * p * (1 - p)

# Calculate skewness
skewness = skew(data_FL)

# Calculate kurtosis
kurtosis = 3 - 6 / (n + 1)

print("Mean (Center):", mean)
print("Variance:", variance)
print("Skewness:", skewness)
print("Kurtosis:", kurtosis)
# Out:
# Mean (Center): 13915.0
# Variance: 6957.5
# Skewness: 6.133121388833411
# Kurtosis: 2.9997844130645683

# %%
NY_df= df[df['State']=='NY']
NC_df= df[df['State']=='NC']
SC_df= df[df['State']=='SC']
CA_df= df[df['State']=='CA']
NJ_df= df[df['State']=='NJ']

##Florida_df.head()


data_NY =NY_df.iloc[:,4:].values.flatten()
data_NC =NC_df.iloc[:,4:].values.flatten()
data_SC =SC_df.iloc[:,4:].values.flatten()
data_CA =CA_df.iloc[:,4:].values.flatten()
data_NJ =NJ_df.iloc[:,4:].values.flatten()

# %%
plt.hist(data_NY, bins=50, alpha=0.7, density=True, label='Data')

# Fit a normal distribution
mu = np.mean(data_NY)  # Mean of the sample
sigma = np.std(data_NY)  # Standard deviation of the sample
x = np.linspace(np.min(data_NY), np.max(data_NY), 100)
plt.plot(x, norm.pdf(x, mu, sigma), 'r-', label='Normal fit')

plt.xlabel('Values')
plt.ylabel('Probability Density')
plt.title('Histogram and Normal Fit for PMF (NY)')
plt.legend()
plt.grid(True)
plt.show()

mean = n * p

# Calculate variance
variance = n * p * (1 - p)

# Calculate skewness
skewness = skew(data_NY)

# Calculate kurtosis
kurtosis = 3 - 6 / (n + 1)

print("Mean (Center):", mean)
print("Variance:", variance)
print("Skewness:", skewness)
print("Kurtosis:", kurtosis)
# Out:
# Mean (Center): 13915.0
# Variance: 6957.5
# Skewness: 4.055979055579067
# Kurtosis: 2.9997844130645683

# %%
plt.hist(data_NC, bins=50, alpha=0.7, density=True, label='Data')

# Fit a normal distribution
mu = np.mean(data_NC)  # Mean of the sample
sigma = np.std(data_NC)  # Standard deviation of the sample
x = np.linspace(np.min(data_NC), np.max(data_NC), 100)
plt.plot(x, norm.pdf(x, mu, sigma), 'r-', label='Normal fit')

plt.xlabel('Values')
plt.ylabel('Probability Density')
plt.title('Histogram and Normal Fit for PMF (NC)')
plt.legend()
plt.grid(True)
plt.show()

mean = n * p

# Calculate variance
variance = n * p * (1 - p)

# Calculate skewness
skewness = skew(data_NC)

# Calculate kurtosis
kurtosis = 3 - 6 / (n + 1)

print("Mean (Center):", mean)
print("Variance:", variance)
print("Skewness:", skewness)
print("Kurtosis:", kurtosis)
# Out:
# Mean (Center): 13915.0
# Variance: 6957.5
# Skewness: 6.341328914505629
# Kurtosis: 2.9997844130645683

# %%
plt.hist(data_SC, bins=50, alpha=0.7, density=True, label='Data')

# Fit a normal distribution
mu = np.mean(data_SC)  # Mean of the sample
sigma = np.std(data_SC)  # Standard deviation of the sample
x = np.linspace(np.min(data_SC), np.max(data_SC), 100)
plt.plot(x, norm.pdf(x, mu, sigma), 'r-', label='Normal fit')

plt.xlabel('Values')
plt.ylabel('Probability Density')
plt.title('Histogram and Normal Fit for PMF (SC)')
plt.legend()
plt.grid(True)
plt.show()

mean = n * p

# Calculate variance
variance = n * p * (1 - p)

# Calculate skewness
skewness = skew(data_SC)

# Calculate kurtosis
kurtosis = 3 - 6 / (n + 1)

print("Mean (Center):", mean)
print("Variance:", variance)
print("Skewness:", skewness)
print("Kurtosis:", kurtosis)
# Out:
# Mean (Center): 13915.0
# Variance: 6957.5
# Skewness: 2.705957679615541
# Kurtosis: 2.9997844130645683

# %%
plt.hist(data_CA, bins=50, alpha=0.7, density=True, label='Data')

# Fit a normal distribution
mu = np.mean(data_CA)  # Mean of the sample
sigma = np.std(data_CA)  # Standard deviation of the sample
x = np.linspace(np.min(data_CA), np.max(data_CA), 100)
plt.plot(x, norm.pdf(x, mu, sigma), 'r-', label='Normal fit')

plt.xlabel('Values')
plt.ylabel('Probability Density')
plt.title('Histogram and Normal Fit for PMF (CA)')
plt.legend()
plt.grid(True)
plt.show()

mean = n * p

# Calculate variance
variance = n * p * (1 - p)

# Calculate skewness
skewness = skew(data_CA)

# Calculate kurtosis
kurtosis = 3 - 6 / (n + 1)

print("Mean (Center):", mean)
print("Variance:", variance)
print("Skewness:", skewness)
print("Kurtosis:", kurtosis)
# Out:
# Mean (Center): 13915.0
# Variance: 6957.5
# Skewness: 7.768969821058437
# Kurtosis: 2.9997844130645683

# %%
plt.hist(data_NJ, bins=50, alpha=0.7, density=True, label='Data')

# Fit a normal distribution
mu = np.mean(data_NJ)  # Mean of the sample
sigma = np.std(data_NJ)  # Standard deviation of the sample
x = np.linspace(np.min(data_NJ), np.max(data_NJ), 100)
plt.plot(x, norm.pdf(x, mu, sigma), 'r-', label='Normal fit')

plt.xlabel('Values')
plt.ylabel('Probability Density')
plt.title('Histogram and Normal Fit for PMF (NJ)')
plt.legend()
plt.grid(True)
plt.show()

mean = n * p

# Calculate variance
variance = n * p * (1 - p)

# Calculate skewness
skewness = skew(data_NJ)

# Calculate kurtosis
kurtosis = 3 - 6 / (n + 1)

print("Mean (Center):", mean)
print("Variance:", variance)
print("Skewness:", skewness)
print("Kurtosis:", kurtosis)
# Out:
# Mean (Center): 13915.0
# Variance: 6957.5
# Skewness: 1.3004041950738874
# Kurtosis: 2.9997844130645683

# %% [markdown]
# Now lets use poission modeling for cases and deaths

# %% [markdown]
# # Question 2

# %%
death_df=pd.read_csv('covid_deaths_usafacts.csv')
pop_df=pd.read_csv('covid_county_population_usafacts.csv')

# %%
state_pop=pop_df[pop_df['State']=='FL']
state_deaths=death_df[death_df['State']=='FL']
pop_of_state= state_pop['population'].sum()
fl_cases_per= data_FL/(pop_of_state/1000)
deaths_FL =state_deaths.iloc[:,4:].values.flatten()
fl_deaths_per= deaths_FL/ (pop_of_state/1000)

# %%
plt.hist(fl_cases_per, bins=50, alpha=0.7, density=True, label='Data')
mu_cases = np.mean(fl_cases_per)
x_cases = np.arange(0, np.max(fl_cases_per) + 1)
plt.plot(x_cases, poisson.pmf(x_cases, mu_cases), 'r-', label='Poisson fit')
plt.xlabel('Cases per 1000 people')
plt.ylabel('Probability Mass')
plt.title('Histogram and Poisson Fit for PMF for Cases in FL')
plt.legend()
plt.grid(True)
plt.show()





plt.hist(fl_deaths_per, bins=50, alpha=0.7, density=True, label='Data')
mu_deaths = np.mean(fl_deaths_per)
x_deaths = np.arange(0, np.max(fl_deaths_per) + 1)
plt.plot(x_deaths, poisson.pmf(x_deaths, mu_deaths), 'r-', label='Poisson fit')
plt.xlabel('Deaths per 1000 people')
plt.ylabel('Probability Mass')
plt.title('Histogram and Poisson Fit for PMF for Deaths in FL')
plt.legend()
plt.grid(True)
plt.show()

# %%
state_pop=pop_df[pop_df['State']=='NY']
state_deaths=death_df[death_df['State']=='NY']
pop_of_state= state_pop['population'].sum()
NY_cases_per= data_NY/(pop_of_state/1000)
deaths_NY =state_deaths.iloc[:,4:].values.flatten()
NY_deaths_per= deaths_NY/ (pop_of_state/1000)

plt.hist(NY_cases_per, bins=50, alpha=0.7, density=True, label='Data')

# Fit a Poisson distribution
mu = np.mean(NY_cases_per)  # Parameter for Poisson distribution
x = np.arange(0, np.max(NY_cases_per) + 1)
plt.plot(x, poisson.pmf(x, mu), 'r-', label='Poisson fit')

plt.xlabel('Values')
plt.ylabel('Probability Mass')
plt.title('Histogram and Poisson Fit for PMF for Cases in NY')
plt.legend()
plt.grid(True)
plt.show()


plt.hist(NY_deaths_per, bins=50, alpha=0.7, density=True, label='Data')

# Fit a Poisson distribution
mu = np.mean(NY_deaths_per)  # Parameter for Poisson distribution
x = np.arange(0, np.max(NY_deaths_per) + 1)
plt.plot(x, poisson.pmf(x, mu), 'r-', label='Poisson fit')

plt.xlabel('Values')
plt.ylabel('Probability Mass')
plt.title('Histogram and Poisson Fit for PMF for Deaths in NY')
plt.legend()
plt.grid(True)
plt.show()

# %%
state_pop=pop_df[pop_df['State']=='NC']
state_deaths=death_df[death_df['State']=='NC']
pop_of_state= state_pop['population'].sum()
NC_cases_per= data_NC/(pop_of_state/1000)
deaths_NC =state_deaths.iloc[:,4:].values.flatten()
NC_deaths_per= deaths_NC/ (pop_of_state/1000)

plt.hist(NC_cases_per, bins=50, alpha=0.7, density=True, label='Data')

# Fit a Poisson distribution
mu = np.mean(NC_cases_per)  # Parameter for Poisson distribution
x = np.arange(0, np.max(NC_cases_per) + 1)
plt.plot(x, poisson.pmf(x, mu), 'r-', label='Poisson fit')

plt.xlabel('Values')
plt.ylabel('Probability Mass')
plt.title('Histogram and Poisson Fit for PMF for Cases in NC')
plt.legend()
plt.grid(True)
plt.show()


plt.hist(NC_deaths_per, bins=50, alpha=0.7, density=True, label='Data')

# Fit a Poisson distribution
mu_NC = np.mean(NC_deaths_per)  # Parameter for Poisson distribution
x_NC = np.arange(0, np.max(NC_deaths_per) + 1)
plt.plot(x_NC, poisson.pmf(x_NC, mu_NC), 'r-', label='Poisson fit')

plt.xlabel('Values')
plt.ylabel('Probability Mass')
plt.title('Histogram and Poisson Fit for PMF for Deaths in NC')
plt.legend()
plt.grid(True)
plt.show()

# %%
state_pop=pop_df[pop_df['State']=='NJ']
state_deaths=death_df[death_df['State']=='NJ']
pop_of_state= state_pop['population'].sum()
NJ_cases_per= data_NJ/(pop_of_state/1000)
deaths_NJ =state_deaths.iloc[:,4:].values.flatten()
NJ_deaths_per= deaths_NJ/ (pop_of_state/1000)

plt.hist(NJ_cases_per, bins=50, alpha=0.7, density=True, label='Data')

# Fit a Poisson distribution
mu = np.mean(NJ_cases_per)  # Parameter for Poisson distribution
x = np.arange(0, np.max(NJ_cases_per) + 1)
plt.plot(x, poisson.pmf(x, mu), 'r-', label='Poisson fit')

plt.xlabel('Values')
plt.ylabel('Probability Mass')
plt.title('Histogram and Poisson Fit for PMF for Cases in NJ')
plt.legend()
plt.grid(True)
plt.show()


plt.hist(NJ_deaths_per, bins=50, alpha=0.7, density=True, label='Data')

# Fit a Poisson distribution
mu_NJ = np.mean(NJ_deaths_per)  # Parameter for Poisson distribution
x_NJ = np.arange(0, np.max(NJ_deaths_per) + 1)
plt.plot(x_NJ, poisson.pmf(x_NJ, mu_NJ), 'r-', label='Poisson fit')

plt.xlabel('Values')
plt.ylabel('Probability Mass')
plt.title('Histogram and Poisson Fit for PMF for Deaths in NJ')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Question 3

# %%
election_df=pd.read_csv('governors_county.csv')
NC_df = election_df[(election_df['state'] == 'North Carolina')]
state_pop=pop_df[pop_df['State']=='NC']
pop_of_state= state_pop['population'].sum()
NC_df.head()
NC_votes =NC_df.iloc[:,2].values.flatten()
NC_votes_per= NC_votes/(pop_of_state/1000)



data_NC
# Out:
# array([   0,    0,    0, ..., 6419, 6419, 6419], dtype=int64)

# %%
min_length = min(len(NC_votes_per), len(NC_cases_per))

# Trim the longer array to match the minimum length
NC_votes_per = NC_votes_per[:min_length]
NC_cases_per = NC_cases_per[:min_length]


plt.scatter(NC_votes_per, NC_cases_per, alpha=0.7)
plt.xlabel('Votes per 1000 people')
plt.ylabel('Cases per 1000 people')
plt.title('Correlation between Votes and Cases in NC')
plt.grid(True)
plt.show()

# %% [markdown]
# # Question 4

# %% [markdown]
# Variable 1 Hypotheseis: The less votes in the area the less amount of cases
#
# The rationale behind this hypothesis could be that areas with higher voter turnout may also have higher levels of awareness about public health measures, leading to better adherence to guidelines such as mask-wearing and social distancing. Consequently, these areas may experience lower rates of COVID-19 transmission compared to areas with lower voter turnout where public health awareness and adherence to guidelines may be lower.

# %% [markdown]
# Variable 2 Hypotheseis: The higer the percent of voters in a county gives a higher percent of population in that county getting covid
#
# One possible explanation for this hypothesis is that areas with higher voter turnout may also have higher population density or more social interaction, leading to increased transmission of the virus. Additionally, areas with high voter turnout may be more densely populated urban areas where COVID-19 transmission rates tend to be higher due to factors such as crowded living conditions and increased mobility.

# %% [markdown]
# Variable 3 Hypotheseis: The countys that do not have a big city within them will caues both votes and cases to be lower than a county with a big city.
#
# Counties with major cities often have higher population densities, greater social interaction, and more diverse populations, which may contribute to higher rates of both voter turnout and COVID-19 transmission. In contrast, rural counties or those without major urban centers may have lower voter turnout due to factors such as lower population density, fewer polling locations, and lower levels of civic engagement. Similarly, these areas may also experience lower COVID-19 transmission rates due to reduced population density and less social interaction compared to urban areas.
